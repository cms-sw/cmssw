# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import math

# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %%
def split(row) :
    r = []
    for i in range(3,10) : r.append(row[i])
    return (int(row[2])+100*(int(row[1])+10*int(row[0])), np.array(r),[int(row[11]),int(row[13])])
types = []
types += 3*[int] +8*[float] + 2*[int,float]
f90 = open("../data/pixelShapePhase1_all.par", "r").readlines()
pcsf = np.genfromtxt(f90)


f451 = open("../data/pixelShapePhase1_all.par", "r").readlines()
pcsf1 = np.genfromtxt(f451) #,dtype=types)
map1 = {}
for r in pcsf1 :
    i,c,n = split(r)
    map1[i]=(c,n)
#print map1[111]


f452 = open("../data/pixelShapePhase1_noL1.par", "r").readlines()
map2 = {}
pcsf2 = np.genfromtxt(f452) #,dtype=types)
for r in pcsf2 :
    i,c,n = split(r)
    map2[i]=(c,n)
#xy1 = np.genfromtxt(f451, usecols=(3,4,5,6,7,8,9,10))
#xy2 = np.genfromtxt(f452, usecols=(3,4,5,6,7,8,9,10))
#for r in pcsf :
#    if r[2]==0 : print r

# %%
def ylim(row) :
    return (min(row[5],-row[10]),max(row[6],-row[9]))
def xlim(row) :
    return (min(row[3],-row[8]),max(row[4],-row[7]))

# %%
#for r in pcsf :
# print r[2],ylim(r)

# %%
def ploty(ax,pcsf,col='b',barrel=0) :
    for r in pcsf :
        if (r[0]!=barrel) : continue
        x = []
        y = []
        x.append(r[2])
        x.append(r[2])
        x.append(r[2]+1)
        x.append(r[2]+1)
        l = ylim(r)
        y.append(l[0])
        y.append(l[1])
        y.append(l[1])
        y.append(l[0])
        ax.fill(y, x, col,alpha=0.2)
    ax.set_xlabel('predicted y size',fontsize=14)
    ax.set_ylabel('measured x size',fontsize=14)

def plotx(ax,pcsf,col='b',barrel=0) :
    for r in pcsf :
        if (r[0]!=barrel) : continue
        x = []
        y = []
        x.append(r[1])
        x.append(r[1])
        x.append(r[1]+1)
        x.append(r[1]+1)
        l = xlim(r)
        y.append(l[0])
        y.append(l[1])
        y.append(l[1])
        y.append(l[0])
        ax.fill(y, x, col,alpha=0.2)
    ax.set_xlabel('predicted x size',fontsize=14)
    ax.set_ylabel('measured x size',fontsize=14)

# %%
fig, ax = plt.subplots(figsize=(14, 8))
ploty(ax,pcsf,'b',0)
ax.set_title('Barrel Y')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(14, 8))
ploty(ax,pcsf,'b',1)
ax.set_title('Forward Y')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(14, 8))
plotx(ax,pcsf,'b',0)
ax.set_title('Barrel X')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(14, 8))
plotx(ax,pcsf,'b',1)
ax.set_title('Forward X')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(14, 8))
ploty(ax,pcsf1,'g',0)
ploty(ax,pcsf2,'r',0)
ax.set_title('Barrel Y')
ax.text(0, 14, 'all clusters',color='g',fontsize=14)
ax.text(0, 12, 'w/o BPIX1',color='r',fontsize=14)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(14, 8))
plotx(ax,pcsf1,'g',0)
plotx(ax,pcsf2,'r',0)
ax.set_title('Barrel X')
plt.show()

# %%
dxy = []
for k in map1.keys() :
    if k in map2.keys() :
        d = map2[k][0]-map1[k][0]
        if (max(d)<100 and min(d)>-100) :
            dxy.append(d)
            if max(d) >1 : print k,d,map2[k][1],map1[k][1]
            if min(d) <-1 : print k,d,map2[k][1],map1[k][1]
plt.hist(dxy,bins=50, normed=1)
plt.show()
# Out:
# 3 [ 0.050461 -0.00588  -0.00144  -1.13216   0.058117 -0.02567   1.20359 ] [3112, 3293] [3296, 3346]
# 3 [ 0.050461 -0.00588  -0.00144  -1.13216   0.058117 -0.02567   1.20359 ] [3112, 3293] [3296, 3346]
# 4 [ 0.010162 -0.10886   0.00313  -3.08253  -0.044705 -0.18037   2.30214 ] [1942, 1638] [1498, 1526]
# 4 [ 0.010162 -0.10886   0.00313  -3.08253  -0.044705 -0.18037   2.30214 ] [1942, 1638] [1498, 1526]
# 5 [ 0.083755 -0.2295   -0.0794   -5.13733   0.111318 -0.1916    4.57214 ] [1160, 1333] [707, 807]
# 5 [ 0.083755 -0.2295   -0.0794   -5.13733   0.111318 -0.1916    4.57214 ] [1160, 1333] [707, 807]
# 6 [ 0.037792 -0.28313   0.06848  -5.74361   0.007536 -0.18186   5.06985 ] [850, 792] [487, 577]
# 6 [ 0.037792 -0.28313   0.06848  -5.74361   0.007536 -0.18186   5.06985 ] [850, 792] [487, 577]
# 7 [-0.063356 -0.26894   0.19705  -6.77911  -0.040049 -0.09972   6.23528 ] [528, 475] [332, 368]
# 7 [-0.063356 -0.26894   0.19705  -6.77911  -0.040049 -0.09972   6.23528 ] [528, 475] [332, 368]
# 8 [ -1.73400000e-03  -8.48000000e-03   1.01850000e-01  -5.88942000e+00
#   -2.72809000e-01  -2.26350000e-01   6.91315000e+00] [205, 215] [270, 247]
# 8 [ -1.73400000e-03  -8.48000000e-03   1.01850000e-01  -5.88942000e+00
#   -2.72809000e-01  -2.26350000e-01   6.91315000e+00] [205, 215] [270, 247]
# 9 [ -1.97307000e-01  -1.85224000e-01   1.66000000e-03  -5.73503000e+00
#   -2.28399000e-01  -3.16942000e-01   6.17870000e+00] [56, 66] [234, 211]
# 9 [ -1.97307000e-01  -1.85224000e-01   1.66000000e-03  -5.73503000e+00
#   -2.28399000e-01  -3.16942000e-01   6.17870000e+00] [56, 66] [234, 211]
# 600 [ 0.1156    3.27937   0.003578 -0.016258  0.00869  -0.06998   0.098931] [19, 11] [103, 23]
# 101 [ 0.053555 -0.02515  -1.00218  -0.95669  -2.585218 -0.21082  -5.112611] [96611, 35] [61569, 93037]
# 103 [ -9.16537000e-02  -6.27800000e-02  -2.48000000e-03  -1.12712000e+00
#    1.23600000e-02   3.60000000e-06   4.39500000e-02] [49823, 831] [51798, 819]
# 104 [ -4.69200000e-03  -5.10000000e-04   3.00000000e-05  -1.64490000e+00
#    2.33200000e-02   5.60000000e-06   1.31050000e-01] [30885, 427] [30362, 400]
